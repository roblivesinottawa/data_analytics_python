# %% [markdown]
# ## Importing Data with NumPy

# %% [markdown]
# ### 1. Run the following cells:

# %%
import numpy as np

# %%
np.set_printoptions(suppress = True, linewidth = 150)

# %% [markdown]
# ### 2. Use loadtxt() to import the same file and display its contents.
#    <b> Hint:</b> By default np.loadtxt() asusmes all the values will be numeric, so it crashes when it encounters text data. We can bypass this by specifying the datatype to NumPy strings when importing.

# %%
lending_co_TP = np.loadtxt("Lending-Company-Total-Price.csv", delimiter = ',', dtype = str)

# %%
lending_co_TP
# Out:
# array([['LoanID', 'StringID', 'Product', ..., 'Location', 'Region', 'TotalPrice'],
#        ['1', 'id_1', 'Product B', ..., 'Location 2', 'Region 2', '16600'],
#        ['2', 'id_2', 'Product B', ..., 'Location 3', '', '16600'],
#        ...,
#        ['413', 'id_413', 'Product B', ..., 'Location 135', 'Region 1', '16600'],
#        ['414', 'id_414', 'Product C', ..., 'Location 200', 'Region 6', '15600'],
#        ['415', 'id_415', 'Product A', ..., 'Location 8', 'Region 2', '22250']], dtype='<U14')

# %% [markdown]
# ### 3. Use np.genfromtxt() to import the "Lending-Company-Total-Price.csv" file and display its contents.
#     You can open the file in a text editor like Notepad++ to check its delimiter.

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price.csv", delimiter = ',')

# %%
lending_co_TP
# Out:
# array([[   nan,    nan,    nan, ...,    nan,    nan,    nan],
#        [    1.,    nan,    nan, ...,    nan,    nan, 16600.],
#        [    2.,    nan,    nan, ...,    nan,    nan, 16600.],
#        ...,
#        [  413.,    nan,    nan, ...,    nan,    nan, 16600.],
#        [  414.,    nan,    nan, ...,    nan,    nan, 15600.],
#        [  415.,    nan,    nan, ...,    nan,    nan, 22250.]])

# %% [markdown]
# ### 4. Using the arguments of the np.genfromtxt() function, do the following data cleaning:
#     A) Set the data type to strings.
#     B) Skip the first row of the dataset.
#     C) Skip the last 15 rows of the dataset.
#     D) Only pull data from the 2nd, 3rd and 5th columns.
#    (Note: You can do all of these at the same time.)

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price.csv",
                                delimiter=',',
                                dtype = str,
                                skip_header=0,
                                skip_footer=15,
                                usecols=(1, 2, 4))

lending_co_TP
# Out:
# array([['StringID', 'Product', 'Location'],
#        ['id_1', 'Product B', 'Location 2'],
#        ['id_2', 'Product B', 'Location 3'],
#        ...,
#        ['id_398', 'Product A', 'Location 29'],
#        ['id_399', 'Product B', 'Location 73'],
#        ['id_400', 'Product B', 'Location 53']], dtype='<U12')

# %% [markdown]
# ### 5. Refer to the documentation of the np.genfromtxt() function and examine the following arguments and what they do:
#     A) comments
#     B) converters
#     C) missing_values
#     D) excludelist
#     E) deletechars
#     D) replace_space
#     E) autostrip
#    (You're <b>not</b> expected to provide any coding for this part. The cell below is provided for your convenience in case you want to try using the arguments as you go through them.)

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price.csv",
                              delimiter=',',
                              dtype = str,
                              skip_header = 0,
                              skip_footer = 15,
                              usecols = (1, 2, 4),
                              comments = '#',
                              converters = None,
                              missing_values = None,
                              excludelist = None,
                              deletechars = " !#$%&'()*+,-./:;<=>?@[\\]^{|}~",
                              replace_space = '_',
                              autostrip = True
                              )

lending_co_TP
# Out:
# array([['StringID', 'Product', 'Location'],
#        ['id_1', 'Product B', 'Location 2'],
#        ['id_2', 'Product B', 'Location 3'],
#        ...,
#        ['id_398', 'Product A', 'Location 29'],
#        ['id_399', 'Product B', 'Location 73'],
#        ['id_400', 'Product B', 'Location 53']], dtype='<U12')

# %% [markdown]
# ### 6. Now that you understand what these arguments do, add them to the code you wrote a few cells ago.
#     A) comments
#     B) converters
#     C) missing_values
#     D) excludelist
#     E) deletechars
#     D) replace_space
#     E) autostrip
#    <b>Note</b>: If you don't know what values to set, just refer to the documentation and set the defaults.

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price.csv",
                              delimiter=',',
                              dtype = str,
                              skip_header = 0,
                              skip_footer = 15,
                              usecols = (1, 2, 4),
                              comments = '#',
                              converters = None,
                              missing_values = None,
                              excludelist = None,
                              deletechars = " !#$%&'()*+,-./:;<=>?@[\\]^{|}~",
                              replace_space = '_',
                              autostrip = True
                              )

lending_co_TP
# Out:
# array([['StringID', 'Product', 'Location'],
#        ['id_1', 'Product B', 'Location 2'],
#        ['id_2', 'Product B', 'Location 3'],
#        ...,
#        ['id_398', 'Product A', 'Location 29'],
#        ['id_399', 'Product B', 'Location 73'],
#        ['id_400', 'Product B', 'Location 53']], dtype='<U12')

# %% [markdown]
# ### 7. The first and last columns were the only ones with numeric data, so let's import only them.

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price.csv",
                                delimiter=',',
                                dtype=str,
                                skip_header=1,
                                usecols=(0,-1))

lending_co_TP
# Out:
# array([['1', '16600'],
#        ['2', '16600'],
#        ['3', '15600'],
#        ['4', '16600'],
#        ['5', '20250'],
#        ['6', ''],
#        ['7', '20250'],
#        ['8', '16600'],
#        ['9', '22250'],
#        ['10', '20250'],
#        ['11', '16600'],
#        ['12', '20250'],
#        ['13', '16600'],
#        ['14', '20750'],
#        ['15', '22250'],
#        ['16', '16600'],
#        ['17', '22250'],
#        ['18', '16600'],
#        ['19', '16600'],
#        ['20', '54625'],
#        ['21', '16600'],
#        ['22', '22250'],
#        ['23', '19250'],
#        ['24', '15600'],
#        ['25', '20250'],
#        ['26', '22250'],
#        ['27', '19250'],
#        ['28', '69225'],
#        ['29', '20250'],
#        ['30', '16600'],
#        ['31', '16600'],
#        ['32', '16600'],
#        ['33', '19250'],
#        ['34', '16600'],
#        ['35', '19250'],
#        ['36', '16600'],
#        ['37', '16600'],
#        ['38', '16600'],
#        ['39', '15600'],
#        ['40', '16600'],
#        ['41', '16600'],
#        ['42', '16600'],
#        ['43', '19250'],
#        ['44', '15600'],
#        ['45', '19250'],
#        ['46', '16600'],
#        ['47', '16600'],
#        ['48', '16600'],
#        ['49', '20250'],
#        ['50', '22250'],
#        ['51', '16600'],
#        ['52', '20250'],
#        ['53', '20250'],
#        ['54', '16600'],
#        ['55', '16600'],
#        ['56', '16600'],
#        ['57', ''],
#        ['58', '16600'],
#        ['59', '16600'],
#        ['60', '16600'],
#        ['61', '19250'],
#        ['62', '15600'],
#        ['63', '15600'],
#        ['64', '20250'],
#        ['65', '16600'],
#        ['66', '22250'],
#        ['67', '22250'],
#        ['68', '20250'],
#        ['69', '20250'],
#        ['70', '16600'],
#        ['71', '15600'],
#        ['72', '16600'],
#        ['73', '16600'],
#        ['74', '22250'],
#        ['75', '20750'],
#        ['76', '22250'],
#        ['77', '19250'],
#        ['78', '20250'],
#        ['79', '20250'],
#        ['80', '20250'],
#        ['81', '19250'],
#        ['82', '16600'],
#        ['83', '22250'],
#        ['84', '20250'],
#        ['85', '16600'],
#        ['86', '19250'],
#        ['87', '22250'],
#        ['88', '16600'],
#        ['89', '19250'],
#        ['90', '16600'],
#        ['91', ''],
#        ['92', '20250'],
#        ['93', '16600'],
#        ['94', '16600'],
#        ['95', '19250'],
#        ['96', '16600'],
#        ['97', '16600'],
#        ['98', '22250'],
#        ['99', '22250'],
#        ['100', '16600'],
#        ['101', '16600'],
#        ['102', '19250'],
#        ['103', '16600'],
#        ['104', '22250'],
#        ['105', '19250'],
#        ['106', '16600'],
#        ['107', '16600'],
#        ['108', '19250'],
#        ['109', '16600'],
#        ['110', '22250'],
#        ['111', '16600'],
#        ['112', '15600'],
#        ['113', '16600'],
#        ['114', '20250'],
#        ['115', '16600'],
#        ['116', '19250'],
#        ['117', '19250'],
#        ['118', '19250'],
#        ['119', '15600'],
#        ['120', '22250'],
#        ['121', '22250'],
#        ['122', '16600'],
#        ['123', '20250'],
#        ['124', '16600'],
#        ['125', '16600'],
#        ['126', '20750'],
#        ['127', '20250'],
#        ['128', '16600'],
#        ['129', '16600'],
#        ['130', '16600'],
#        ['131', '15600'],
#        ['132', '16600'],
#        ['133', '15600'],
#        ['134', '19250'],
#        ['135', '16600'],
#        ['136', '16600'],
#        ['137', '20250'],
#        ['138', '19250'],
#        ['139', '15600'],
#        ['140', '16600'],
#        ['141', '16600'],
#        ['142', '16600'],
#        ['143', '15600'],
#        ['144', '16600'],
#        ['145', '15600'],
#        ['146', '19250'],
#        ['147', '22250'],
#        ['148', '20250'],
#        ['149', '19250'],
#        ['150', '22250'],
#        ['151', '16600'],
#        ['152', '22250'],
#        ['153', '54625'],
#        ['154', '54625'],
#        ['155', '16600'],
#        ['156', '22250'],
#        ['157', '22250'],
#        ['158', '22250'],
#        ['159', '22250'],
#        ['160', '15600'],
#        ['161', ''],
#        ['162', '16600'],
#        ['163', '22250'],
#        ['164', '20250'],
#        ['165', '22250'],
#        ['166', '16600'],
#        ['167', '19250'],
#        ['168', '20250'],
#        ['169', '16600'],
#        ['170', '20250'],
#        ['171', '16600'],
#        ['172', '16600'],
#        ['173', '20250'],
#        ['174', '20250'],
#        ['175', '16600'],
#        ['176', '20250'],
#        ['177', '19250'],
#        ['178', '16600'],
#        ['179', '20750'],
#        ['180', '20250'],
#        ['181', '22250'],
#        ['182', '16600'],
#        ['183', '20250'],
#        ['184', '20250'],
#        ['185', '16600'],
#        ['186', '20250'],
#        ['187', '20750'],
#        ['188', '16600'],
#        ['189', '16600'],
#        ['190', '22250'],
#        ['191', '22250'],
#        ['192', '22250'],
#        ['193', '16600'],
#        ['194', '54625'],
#        ['195', '16600'],
#        ['196', '22250'],
#        ['197', '16600'],
#        ['198', '20250'],
#        ['199', '22250'],
#        ['200', '15600'],
#        ['201', '20250'],
#        ['202', '16600'],
#        ['203', '54625'],
#        ['204', '16600'],
#        ['205', '16600'],
#        ['206', '22250'],
#        ['207', '19250'],
#        ['208', '19250'],
#        ['209', '19250'],
#        ['210', '22250'],
#        ['211', '15600'],
#        ['212', '22250'],
#        ['213', '15600'],
#        ['214', '16600'],
#        ['215', '22250'],
#        ['216', '22250'],
#        ['217', '16600'],
#        ['218', '20750'],
#        ['219', '19250'],
#        ['220', '16600'],
#        ['221', ''],
#        ['222', '16600'],
#        ['223', '22250'],
#        ['224', '19250'],
#        ['225', '16600'],
#        ['226', '16600'],
#        ['227', '19250'],
#        ['228', '19250'],
#        ['229', '16600'],
#        ['230', '20250'],
#        ['231', '22250'],
#        ['232', '15600'],
#        ['233', '16600'],
#        ['234', '16600'],
#        ['235', '54625'],
#        ['236', '19250'],
#        ['237', '22250'],
#        ['238', '16600'],
#        ['239', '22250'],
#        ['240', '19250'],
#        ['241', '19250'],
#        ['242', '20750'],
#        ['243', '20750'],
#        ['244', '16600'],
#        ['245', '16600'],
#        ['246', '22250'],
#        ['247', '16600'],
#        ['248', '16600'],
#        ['249', '16600'],
#        ['250', '16600'],
#        ['251', '15600'],
#        ['252', '19250'],
#        ['253', '20250'],
#        ['254', '22250'],
#        ['255', '19250'],
#        ['256', '22250'],
#        ['257', '22250'],
#        ['258', '22250'],
#        ['259', '16600'],
#        ['260', '20250'],
#        ['261', '16600'],
#        ['262', '16600'],
#        ['263', '16600'],
#        ['264', '19250'],
#        ['265', '16600'],
#        ['266', '16600'],
#        ['267', '15600'],
#        ['268', '16600'],
#        ['269', '22250'],
#        ['270', '19250'],
#        ['271', ''],
#        ['272', '22250'],
#        ['273', '15600'],
#        ['274', '15600'],
#        ['275', '16600'],
#        ['276', '19250'],
#        ['277', '16600'],
#        ['278', '54625'],
#        ['279', '16600'],
#        ['280', '16600'],
#        ['281', '16600'],
#        ['282', '19250'],
#        ['283', '22250'],
#        ['284', '22250'],
#        ['285', '16600'],
#        ['286', '19250'],
#        ['287', '19250'],
#        ['288', '15600'],
#        ['289', '54625'],
#        ['290', '16600'],
#        ['291', '16600'],
#        ['292', '15600'],
#        ['293', '20250'],
#        ['294', '19250'],
#        ['295', '19250'],
#        ['296', '15600'],
#        ['297', '15600'],
#        ['298', '19250'],
#        ['299', '16600'],
#        ['300', '20250'],
#        ['301', '20750'],
#        ['302', '16600'],
#        ['303', '16600'],
#        ['304', '16600'],
#        ['305', '22250'],
#        ['306', '16600'],
#        ['307', '22250'],
#        ['308', '20250'],
#        ['309', '16600'],
#        ['310', '19250'],
#        ['311', '22250'],
#        ['312', '16600'],
#        ['313', '15600'],
#        ['314', '16600'],
#        ['315', '16600'],
#        ['316', '15600'],
#        ['317', '16600'],
#        ['318', '20250'],
#        ['319', '19250'],
#        ['320', '20250'],
#        ['321', '16600'],
#        ['322', '22250'],
#        ['323', '16600'],
#        ['324', '22250'],
#        ['325', '22250'],
#        ['326', '19250'],
#        ['327', '54625'],
#        ['328', '13775'],
#        ['329', '16600'],
#        ['330', '16600'],
#        ['331', ''],
#        ['332', '20750'],
#        ['333', '16600'],
#        ['334', '19250'],
#        ['335', '22250'],
#        ['336', '20250'],
#        ['337', '22250'],
#        ['338', '19250'],
#        ['339', '16600'],
#        ['340', '15600'],
#        ['341', '20250'],
#        ['342', '22250'],
#        ['343', '22250'],
#        ['344', '16600'],
#        ['345', '22250'],
#        ['346', '20250'],
#        ['347', '16600'],
#        ['348', '22250'],
#        ['349', '19250'],
#        ['350', '16600'],
#        ['351', '16600'],
#        ['352', '15600'],
#        ['353', '19250'],
#        ['354', '16600'],
#        ['355', '20250'],
#        ['356', '16600'],
#        ['357', '22250'],
#        ['358', '16600'],
#        ['359', '15600'],
#        ['360', '20250'],
#        ['361', '22250'],
#        ['362', '20250'],
#        ['363', '16600'],
#        ['364', '22250'],
#        ['365', '16600'],
#        ['366', '16600'],
#        ['367', '16600'],
#        ['368', '20250'],
#        ['369', '16600'],
#        ['370', '16600'],
#        ['371', '16600'],
#        ['372', '19250'],
#        ['373', '20250'],
#        ['374', '16600'],
#        ['375', '16600'],
#        ['376', '22250'],
#        ['377', '19250'],
#        ['378', '22250'],
#        ['379', '16600'],
#        ['380', '19250'],
#        ['381', ''],
#        ['382', '20250'],
#        ['383', '20750'],
#        ['384', '16600'],
#        ['385', '16600'],
#        ['386', '16600'],
#        ['387', '16600'],
#        ['388', '20250'],
#        ['389', '16600'],
#        ['390', '22250'],
#        ['391', '15600'],
#        ['392', '16600'],
#        ['393', '16600'],
#        ['394', '15600'],
#        ['395', '16600'],
#        ['396', '15600'],
#        ['397', '19250'],
#        ['398', '20250'],
#        ['399', '16600'],
#        ['400', '16600'],
#        ['401', '16600'],
#        ['402', '16600'],
#        ['403', '15600'],
#        ['404', '16600'],
#        ['405', '19250'],
#        ['406', '16600'],
#        ['407', '20250'],
#        ['408', '20250'],
#        ['409', '69225'],
#        ['410', '15600'],
#        ['411', '16600'],
#        ['412', '16600'],
#        ['413', '16600'],
#        ['414', '15600'],
#        ['415', '22250']], dtype='<U5')

# %%
# importing json files

# %%
prices_per_product = '{"MacBook Pro": 2000, "iPad": 1000, "iPhone": 1200}'
prices_per_product
# Out:
# '{"MacBook Pro": 2000, "iPad": 1000, "iPhone": 1200}'

# %%
type(prices_per_product)
# Out:
# str

# %%
import json

# %%
parsed_str = json.loads(prices_per_product)
parsed_str
# Out:
# {'MacBook Pro': 2000, 'iPad': 1000, 'iPhone': 1200}

# %%
type(parsed_str)
# Out:
# dict

# %%
import pandas as pd

# %%
new_csv_file = pd.read_json("Lending-Company.json")
new_csv_file
# Out:
#       Loan ID String_ID    Product CustomerGender      Location    Region  \
# 0           1      id_1  Product B           Male    Location 2  Region 2
# 1           2      id_2  Product B           Male    Location 3  Region 3
# 2           3      id_3  Product C         Female    Location 5  Region 5
# 3           4      id_4  Product B           Male    Location 6  Region 1
# 4           5      id_5  Product D         Female    Location 7  Region 2
# ...       ...       ...        ...            ...           ...       ...
# 1038     1039   id_1039  Product B         Female   Location 39  Region 6
# 1039     1040   id_1040  Product B           Male   Location 50  Region 1
# 1040     1041   id_1041  Product B           Male   Location 23  Region 4
# 1041     1042   id_1042  Product C   NotSpecified   Location 52  Region 6
# 1042     1043   id_1043  Product B         Female  Location 142  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDays  AmountPaid30  \
# 0          16600    7/4/2014     2000         40        365          3121
# 1          16600    1/2/2015     2000         40        365          3061
# 2          15600   12/8/2012     1000         40        365          2160
# 3          16600   2/20/2015     2000         40        365          3041
# 4          20250  10/28/2013     2000         50        365          3470
# ...          ...         ...      ...        ...        ...           ...
# 1038       16600  12/29/2014     2000         40        365          3401
# 1039       16600   3/28/2014     2000         40        365          4240
# 1040       16600   4/26/2014     2000         40        365          4201
# 1041       15600  10/25/2012     1000         40        365          2080
# 1042       16600   5/15/2015     2000         40        365          4601
#
#       AmountPaid60  AmountPaid360     LoanStatus360
# 0             4241          13621            Active
# 1             4171          15041            Active
# 2             3280          15340              None
# 3             4241          15321            Active
# 4             4820          13720            Active
# ...            ...            ...               ...
# 1038          4601          16600  Finished Payment
# 1039          5440          16600  Finished Payment
# 1040          5001          16600  Finished Payment
# 1041          3320          15600  Finished Payment
# 1042          4601          16600  Finished Payment
#
# [1043 rows x 15 columns]

# %%
type(new_csv_file)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd 

filename = 'Lending-Company.xlsx'
my_xlsx_file = pd.read_excel(filename)

my_xlsx_file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e4ae1db9b5bf> in <module>
#       2
#       3 filename = 'Lending-Company.xlsx'
# ----> 4 my_xlsx_file = pd.read_excel(filename)
#       5
#       6 my_xlsx_file
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1193                 )
#    1194                 if ext is None:
# -> 1195                     raise ValueError(
#    1196                         "Excel file format cannot be determined, you must specify "
#    1197                         "an engine manually."
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
location_data = pd.read_csv("Lending-company.csv", usecols = ['StringID', 'Location', 'Region'], index_col = 'StringID')
location_data.head()
# Out:
#              Location    Region
# StringID
# LoanID_1   Location 3  Region 2
# LoanID_2   Location 6  Region 6
# LoanID_3   Location 8  Region 3
# LoanID_4  Location 26  Region 2
# LoanID_5  Location 34  Region 3

# %%
import pandas as pd

# %%
my_df = pd.read_csv("Lending-company.csv")
my_df.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# 2       3205       16340        NaN
# 3       4166       16321     Active
# 4       4745       14720     Active

# %%
type(my_df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_usecols = pd.read_csv("Lending-company.csv", usecols=['Product'])
df_usecols.head()
# Out:
#      Product
# 0  Product B
# 1  Product D
# 2  Product B
# 3  Product A
# 4  Product B

# %%
pd.read_csv('/Users/robsontrajano/Desktop/programming/july_2021/Data_Analyst_Course/S10 - Working with Text Files/TEXT-FILES/Lending-company.csv')
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0         NaN     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340               NaN
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
import os, inspect

if '__file__' not in locals():
    fx = inspect.getframeinfo(inspect.currentframe())[0]
else:
    fx = __file__
    
os_dir = os.path.dirname(os.path.abspath(fx))
print(os_dir)
# Out:
# /Users/robsontrajano/Desktop/programming/july_2021/Data_Analyst_Course/S10 - Working with Text Files/L16

# %%
pd.read_csv(os.path.join(os_dir, "Lending-company.csv"))
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0         NaN     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340               NaN
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
import pandas as pd

# %%
filename = 'Lending-company.csv'
my_data = pd.read_csv(filename)
my_data.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# 2       3205       16340        NaN
# 3       4166       16321     Active
# 4       4745       14720     Active

# %%
my_data.to_csv('my-csv-file.csv')

# %%
my_data.to_json('my-json-file.json')

# %%
data = pd.read_json('my-json-file.json')
# data.head()
data
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0        17600.0  04/07/2018     2200         45          365       3221
# 1            NaN  02/01/2019     2200         45          365       3161
# 2        16600.0  08/12/2016     1000         45          365       2260
# 3        17600.0        None     2200         45          365       3141
# 4        21250.0  28/10/2017     2200         55          365       3570
# ...          ...         ...      ...        ...          ...        ...
# 1038     17300.0  29/12/2018     2200         45          365       3251
# 1039         NaN  28/03/2018     2200         45          365       4090
# 1040     17300.0  26/04/2018     2200         45          365       4051
# 1041     16300.0  25/10/2016     1000         45          365       1930
# 1042     17300.0  15/05/2019     2200         45          365       4451
#
#       AmtPaid60  AmtPaid360        LoanStatus
# 0          4166       14621            Active
# 1          4096       16041            Active
# 2          3205       16340              None
# 3          4166       16321            Active
# 4          4745       14720            Active
# ...         ...         ...               ...
# 1038       4743       16617  Finished Payment
# 1039       5582       16617  Finished Payment
# 1040       5143       16617  Finished Payment
# 1041       3462       15617  Finished Payment
# 1042       4743       16617  Finished Payment
#
# [1043 rows x 15 columns]

# %%
data.to_excel('my-excel-file.xlsx')

# %%
pd.read_excel('my-excel-file.xlsx')
# Out:
#       Unnamed: 0  LoanID     StringID    Product CustomerGender     Location  \
# 0              0       1     LoanID_1  Product B         Female   Location 3
# 1              1       2     LoanID_2  Product D         Female   Location 6
# 2              2       3     LoanID_3  Product B           Male   Location 8
# 3              3       4     LoanID_4  Product A           Male  Location 26
# 4              4       5     LoanID_5  Product B         Female  Location 34
# ...          ...     ...          ...        ...            ...          ...
# 1038        1038    1039  LoanID_1039  Product B           Male  Location 73
# 1039        1039    1040  LoanID_1040  Product A           Male  Location 82
# 1040        1040    1041  LoanID_1041  Product A   NotSpecified  Location 11
# 1041        1041    1042  LoanID_1042  Product B         Female  Location 26
# 1042        1042    1043  LoanID_1043  Product A   NotSpecified  Location 94
#
#         Region  TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  \
# 0     Region 2     17600.0  04/07/2018     2200         45          365
# 1     Region 6         NaN  02/01/2019     2200         45          365
# 2     Region 3     16600.0  08/12/2016     1000         45          365
# 3     Region 2     17600.0         NaN     2200         45          365
# 4     Region 3     21250.0  28/10/2017     2200         55          365
# ...        ...         ...         ...      ...        ...          ...
# 1038  Region 6     17300.0  29/12/2018     2200         45          365
# 1039  Region 1         NaN  28/03/2018     2200         45          365
# 1040  Region 4     17300.0  26/04/2018     2200         45          365
# 1041  Region 6     16300.0  25/10/2016     1000         45          365
# 1042  Region 6     17300.0  15/05/2019     2200         45          365
#
#       AmtPaid36  AmtPaid60  AmtPaid360        LoanStatus
# 0          3221       4166       14621            Active
# 1          3161       4096       16041            Active
# 2          2260       3205       16340               NaN
# 3          3141       4166       16321            Active
# 4          3570       4745       14720            Active
# ...         ...        ...         ...               ...
# 1038       3251       4743       16617  Finished Payment
# 1039       4090       5582       16617  Finished Payment
# 1040       4051       5143       16617  Finished Payment
# 1041       1930       3462       15617  Finished Payment
# 1042       4451       4743       16617  Finished Payment
#
# [1043 rows x 16 columns]

# %%
data = pd.read_excel('my-excel-file.xlsx')
data
# Out:
#       Unnamed: 0  LoanID     StringID    Product CustomerGender     Location  \
# 0              0       1     LoanID_1  Product B         Female   Location 3
# 1              1       2     LoanID_2  Product D         Female   Location 6
# 2              2       3     LoanID_3  Product B           Male   Location 8
# 3              3       4     LoanID_4  Product A           Male  Location 26
# 4              4       5     LoanID_5  Product B         Female  Location 34
# ...          ...     ...          ...        ...            ...          ...
# 1038        1038    1039  LoanID_1039  Product B           Male  Location 73
# 1039        1039    1040  LoanID_1040  Product A           Male  Location 82
# 1040        1040    1041  LoanID_1041  Product A   NotSpecified  Location 11
# 1041        1041    1042  LoanID_1042  Product B         Female  Location 26
# 1042        1042    1043  LoanID_1043  Product A   NotSpecified  Location 94
#
#         Region  TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  \
# 0     Region 2     17600.0  04/07/2018     2200         45          365
# 1     Region 6         NaN  02/01/2019     2200         45          365
# 2     Region 3     16600.0  08/12/2016     1000         45          365
# 3     Region 2     17600.0         NaN     2200         45          365
# 4     Region 3     21250.0  28/10/2017     2200         55          365
# ...        ...         ...         ...      ...        ...          ...
# 1038  Region 6     17300.0  29/12/2018     2200         45          365
# 1039  Region 1         NaN  28/03/2018     2200         45          365
# 1040  Region 4     17300.0  26/04/2018     2200         45          365
# 1041  Region 6     16300.0  25/10/2016     1000         45          365
# 1042  Region 6     17300.0  15/05/2019     2200         45          365
#
#       AmtPaid36  AmtPaid60  AmtPaid360        LoanStatus
# 0          3221       4166       14621            Active
# 1          3161       4096       16041            Active
# 2          2260       3205       16340               NaN
# 3          3141       4166       16321            Active
# 4          3570       4745       14720            Active
# ...         ...        ...         ...               ...
# 1038       3251       4743       16617  Finished Payment
# 1039       4090       5582       16617  Finished Payment
# 1040       4051       5143       16617  Finished Payment
# 1041       1930       3462       15617  Finished Payment
# 1042       4451       4743       16617  Finished Payment
#
# [1043 rows x 16 columns]
