# %% [markdown]
# <hr style="border:5px solid #108999"> </hr>

# %% [markdown]
# ## Importing Text Files in Python - ( open() ) <hr style="border:4.5px solid #108999"> </hr>

# %%
filename = "source.txt"

# %%
filename
# Out:
# 'source.txt'

# %%
file = open(filename, mode = 'r')

# %%
file
# Out:
# <_io.TextIOWrapper name='source.txt' mode='r' encoding='UTF-8'>

# %%
file.read()
# Out:
# 'This is the simplest plain text file!\n'

# %%
file = open(filename, mode = 'r')
text = file.read()
text
# Out:
# 'This is the simplest plain text file!\n'

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
print(text)
# Out:
# This is the simplest plain text file!

# %%
filename = 'untitled.txt'

filename
# Out:
# 'untitled.txt'

# %%
file = open(filename, mode= 'r')

file
# Out:
# <_io.TextIOWrapper name='untitled.txt' mode='r' encoding='UTF-8'>

# %%
text = file.read()
text
# Out:
# ''

# %%
file = open(filename, mode= 'r')
text = file.read()
text
# Out:
# 'This is a very simple file to practice using it on jupyter.'

# %%
text
# Out:
# 'This is a very simple file to practice using it on jupyter.'

# %%
text
# Out:
# 'This is a very simple file to practice using it on jupyter.'

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
print(text)
# Out:
# This is a very simple file to practice using it on jupyter.

# %%
text
# Out:
# 'This is a very simple file to practice using it on jupyter.'
